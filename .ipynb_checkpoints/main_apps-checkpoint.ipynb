# %%
# Load Data

import pandas as pd
import joblib

# Load data
def load_data(latih_path, uji_path):
    data_latih = pd.read_excel(latih_path)
    data_uji = pd.read_excel(uji_path)
    return data_latih, data_uji

latih_path = 'data_latih.xlsx'
uji_path = 'data_uji.xlsx'

data_latih, data_uji = load_data(latih_path, uji_path)
data_latih.head(), data_uji.head()
# Out:
# (   Skenario  Curah Hujan (mm/hari)  Suhu (°C)  Kelembaban (%)  \
#  0         1                      2         28              70
#  1         2                     15         30              80
#  2         3                     50         27              85
#  3         4                    100         32              90
#  4         5                      5         26              75
#
#     Kecepatan Angin (km/jam)  Tinggi Muka Air Sungai (m)  \
#  0                         9                         2.0
#  1                        10                         2.5
#  2                        15                         3.0
#  3                        20                         3.5
#  4                        12                         2.3
#
#     Ketinggian Air Tanah (m) Banjir Historis    Label
#  0                       1.5           Tidak     Aman
#  1                       1.8           Tidak  Waspada
#  2                       2.0              Ya    Siaga
#  3                       2.3              Ya     Awas
#  4                       2.0           Tidak     Aman  ,
#          Kecamatan  Latitude  Longitude  Curah Hujan (mm/hari)  Suhu (°C)  \
#  0         Baktiya    5.1048    96.8466                     87         27
#  1   Baktiya Barat    5.0883    96.8067                     23         26
#  2       Cot Girek    4.9557    97.0693                     31         24
#  3       Dewantara    5.2208    96.8424                     39         24
#  4  Geuredong Pase    4.9895    97.1312                     52         28
#
#     Kelembaban (%)  Kecepatan Angin (km/jam)  Tinggi Muka Air Sungai (m)  \
#  0              79                        18                         3.0
#  1              72                        16                         2.5
#  2              77                        13                         3.1
#  3              83                        15                         2.1
#  4              87                        10                         2.1
#
#     Ketinggian Air Tanah (m) Banjir Historis
#  0                       1.8              Ya
#  1                       2.2           Tidak
#  2                       1.7           Tidak
#  3                       1.9           Tidak
#  4                       1.6              Ya  )

# %%
# Persiapan Training Data dari Data Excel
def prepare_training_data(data_latih):
    X_train = data_latih.drop(columns=['Skenario', 'Label', 'Banjir Historis'])
    y_train = data_latih['Label']
    feature_names = X_train.columns.tolist()
    return X_train, y_train, feature_names

X_train, y_train, feature_names = prepare_training_data(data_latih)
X_train.head(), y_train.head()
# Out:
# (   Curah Hujan (mm/hari)  Suhu (°C)  Kelembaban (%)  Kecepatan Angin (km/jam)  \
#  0                      2         28              70                         9
#  1                     15         30              80                        10
#  2                     50         27              85                        15
#  3                    100         32              90                        20
#  4                      5         26              75                        12
#
#     Tinggi Muka Air Sungai (m)  Ketinggian Air Tanah (m)
#  0                         2.0                       1.5
#  1                         2.5                       1.8
#  2                         3.0                       2.0
#  3                         3.5                       2.3
#  4                         2.3                       2.0  ,
#  0       Aman
#  1    Waspada
#  2      Siaga
#  3       Awas
#  4       Aman
#  Name: Label, dtype: object)

# %%
# Proses Training Data
from sklearn.ensemble import RandomForestClassifier

# Train Random Forest model
def train_random_forest(X_train, y_train):
    rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_model.fit(X_train, y_train)
    return rf_model

rf_model = train_random_forest(X_train, y_train)
print("Training Siap !")
# Out:
# Training Siap !

# %%
# Simpan Model
def save_model(model, file_name):
    joblib.dump(model, file_name)

save_model(rf_model, 'rf_model.pkl')
print("Model Disimpan !")
# Out:
# Model Disimpan !

# %%
# Simpan Rules

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree, _tree
import os

# Save the decision tree as a PNG file
def save_decision_tree_as_png(tree, feature_names, class_names, file_name):
    plt.figure(figsize=(20,10))
    plot_tree(
        tree,
        feature_names=feature_names,
        class_names=class_names,
        filled=True,
        rounded=True,
        proportion=True,
        fontsize=10
    )
    plt.savefig(file_name)
    plt.close()

# Extract rules from a tree
def extract_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    rules = []

    def recurse(node, depth, path):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            path_left = f"{path} AND {name} <= {threshold:.2f}"
            path_right = f"{path} AND {name} > {threshold:.2f}"
            recurse(tree_.children_left[node], depth + 1, path_left)
            recurse(tree_.children_right[node], depth + 1, path_right)
        else:
            value = tree_.value[node]
            class_name = class_names[value.argmax()]
            rule = f"IF {path} THEN {class_name}"
            rules.append(rule)

    recurse(0, 1, "True")
    return rules

# Save rules to a text file
def save_rules(rules, file_name):
    with open(file_name, 'w') as f:
        for rule in rules:
            f.write(f"{rule}\n")

class_names = rf_model.classes_.tolist()

os.makedirs('decision_trees', exist_ok=True)
for i in range(min(len(rf_model.estimators_), 10)):  # Save up to the first 10 trees
    file_name = f'decision_trees/tree_{i + 1}.png'
    save_decision_tree_as_png(rf_model.estimators_[i], feature_names, class_names, file_name)
    print(f'Saved {file_name}')
    
    rules = extract_rules(rf_model.estimators_[i], feature_names, class_names)
    save_rules(rules, f'decision_trees/rules_{i + 1}.txt')
    print(f'Saved rules for tree {i + 1}')
# Out:
# Saved decision_trees/tree_1.png
# Saved rules for tree 1
# Saved decision_trees/tree_2.png
# Saved rules for tree 2
# Saved decision_trees/tree_3.png
# Saved rules for tree 3
# Saved decision_trees/tree_4.png
# Saved rules for tree 4
# Saved decision_trees/tree_5.png
# Saved rules for tree 5
# Saved decision_trees/tree_6.png
# Saved rules for tree 6
# Saved decision_trees/tree_7.png
# Saved rules for tree 7
# Saved decision_trees/tree_8.png
# Saved rules for tree 8
# Saved decision_trees/tree_9.png
# Saved rules for tree 9
# Saved decision_trees/tree_10.png
# Saved rules for tree 10

# %%
# Evaluasi Model

from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Evaluate the model
def evaluate_model(model, X_train, y_train):
    cv_scores = cross_val_score(model, X_train, y_train, cv=5)
    train_pred = model.predict(X_train)
    train_accuracy = accuracy_score(y_train, train_pred)
    train_report = classification_report(y_train, train_pred)
    conf_matrix = confusion_matrix(y_train, train_pred)
    return cv_scores, train_accuracy, train_report, conf_matrix

cv_scores, train_accuracy, train_report, conf_matrix = evaluate_model(rf_model, X_train, y_train)

# Display evaluation results
print(f"Cross-Validation Scores: {cv_scores}")
print(f"Mean Cross-Validation Score: {cv_scores.mean()}")
print(f"Training Accuracy: {train_accuracy}")
print(f"Classification Report:\n{train_report}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:725: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# Cross-Validation Scores: [0.75 1.   1.   1.   1.  ]
# Mean Cross-Validation Score: 0.95
# Training Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#         Aman       1.00      1.00      1.00         5
#         Awas       1.00      1.00      1.00         4
#        Siaga       1.00      1.00      1.00         5
#      Waspada       1.00      1.00      1.00         6
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20
#
# Confusion Matrix:
# [[5 0 0 0]
#  [0 4 0 0]
#  [0 0 5 0]
#  [0 0 0 6]]

# %%
# Melakukan Data Uji
def prepare_testing_data(data_uji):
    X_test = data_uji.drop(columns=['Kecamatan', 'Latitude', 'Longitude', 'Banjir Historis'])
    kecamatan = data_uji['Kecamatan']
    latitude = data_uji['Latitude']
    longitude = data_uji['Longitude']
    return X_test, kecamatan, latitude, longitude

X_test, kecamatan, latitude, longitude = prepare_testing_data(data_uji)
X_test.head()
# Out:
#    Curah Hujan (mm/hari)  Suhu (°C)  Kelembaban (%)  Kecepatan Angin (km/jam)  \
# 0                     87         27              79                        18
# 1                     23         26              72                        16
# 2                     31         24              77                        13
# 3                     39         24              83                        15
# 4                     52         28              87                        10
#
#    Tinggi Muka Air Sungai (m)  Ketinggian Air Tanah (m)
# 0                         3.0                       1.8
# 1                         2.5                       2.2
# 2                         3.1                       1.7
# 3                         2.1                       1.9
# 4                         2.1                       1.6

# %%
# Make predictions
def make_predictions(model, X_test):
    return model.predict(X_test)

y_pred = make_predictions(rf_model, X_test)

# Save prediction results to an Excel file and return results DataFrame
def save_prediction_results(kecamatan, y_pred, file_name):
    results = pd.DataFrame({
        'Kecamatan': kecamatan,
        'Prediksi': y_pred
    })
    results.to_excel(file_name, index=False)
    return results

results = save_prediction_results(kecamatan, y_pred, 'hasil_prediksi.xlsx')
results
# Out:
#           Kecamatan Prediksi
# 0           Baktiya     Awas
# 1     Baktiya Barat  Waspada
# 2         Cot Girek  Waspada
# 3         Dewantara     Aman
# 4    Geuredong Pase     Aman
# 5       Kuta Makmur    Siaga
# 6            Lapang  Waspada
# 7         Lhoksukon     Aman
# 8        Matangkuli  Waspada
# 9        Muara Batu     Awas
# 10            Nisam  Waspada
# 11      Paya Bakong  Waspada
# 12         Samudera     Awas
# 13           Sawang     Aman
# 14        Seunuddon    Siaga
# 15  Syamtalira Aron    Siaga
# 16  Syamtalira Bayu    Siaga
# 17  Tanah Jambo Aye    Siaga
# 18       Tanah Luas    Siaga
# 19      Tanah Pasir  Waspada

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# Create a map with Folium
def create_folium_map(kecamatan, latitude, longitude, predictions=None, file_name=None):
    # Create a map centered around the average location
    m = folium.Map(location=[latitude.mean(), longitude.mean()], zoom_start=10)
    marker_cluster = MarkerCluster().add_to(m)

    # Color dictionary for different severity levels
    color_dict = {
        'Aman': 'green',
        'Waspada': 'orange',
        'Siaga': 'red',
        'Awas': 'darkred'
    }

    # Add markers to the map
    for i in range(len(kecamatan)):
        if predictions is not None:
            color = color_dict[predictions[i]]
            popup_text = f"{kecamatan[i]}: {predictions[i]}"
        else:
            color = 'blue'
            popup_text = kecamatan[i]
        
        folium.Marker(
            location=[latitude[i], longitude[i]],
            popup=popup_text,
            icon=folium.Icon(color=color)
        ).add_to(marker_cluster)

    # Save the map to an HTML file
    if file_name:
        m.save(file_name)

    return m

# Display map before predictions
map_before = create_folium_map(kecamatan, latitude, longitude)
display(map_before)

# Create and display map after predictions
map_after = create_folium_map(kecamatan, latitude, longitude, y_pred, 'peta_prediksi.html')
display(map_after)
print("Peta prediksi telah disimpan dalam file 'peta_prediksi.html'")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4458d8d28af88f147d088683e2d73de6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4458d8d28af88f147d088683e2d73de6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4458d8d28af88f147d088683e2d73de6 = L.map(
#                 &quot;map_4458d8d28af88f147d088683e2d73de6&quot;,
#                 {
#                     center: [5.095344999999999, 97.045335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0445d16c1125e26960f7123e006716c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b0445d16c1125e26960f7123e006716c.addTo(map_4458d8d28af88f147d088683e2d73de6);
#
#
#             var marker_cluster_74347a1d029eac775f09c622e5f73e17 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_52ec5829ee9babb5b4bd71296f44874b = L.marker(
#                 [5.1048, 96.8466],
#                 {}
#             ).addTo(marker_cluster_74347a1d029eac775f09c622e5f73e17);
#
#
#             var icon_331b40c593af12d3a83521274e82be98 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52ec5829ee9babb5b4bd71296f44874b.setIcon(icon_331b40c593af12d3a83521274e82be98);
#
#
#         var popup_d0748aab63ca7c7b1ea4e558c09e59ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62118940e693074bc0ecf58e901ebb20 = $(`&lt;div id=&quot;html_62118940e693074bc0ecf58e901ebb20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baktiya&lt;/div&gt;`)[0];
#                 popup_d0748aab63ca7c7b1ea4e558c09e59ee.setContent(html_62118940e693074bc0ecf58e901ebb20);
#
#
#
#         marker_52ec5829ee9babb5b4bd71296f44874b.bindPopup(popup_d0748aab63ca7c7b1ea4e558c09e59ee)
#         ;
#
#
#
#
#             var marker_7fb09b8db3c244ff1a5ddc6f386d95f6 = L.marker(
#                 [5.0883, 96.8067],
#                 {}
#             ).addTo(marker_cluster_74347a1d029eac775f09c622e5f73e17);
#
#
#             var icon_8a446a78e6096055f1f20964218d1bc2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fb09b8db3c244ff1a5ddc6f386d95f6.setIcon(icon_8a446a78e6096055f1f20964218d1bc2);
#
#
#         var popup_425dc90cd55d28aa452798a886d79615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d8f3e55c119347dec7b4891e6ec49b9 = $(`&lt;div id=&quot;html_1d8f3e55c119347dec7b4891e6ec49b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baktiya Barat&lt;/div&gt;`)[0];
#                 popup_425dc90cd55d28aa452798a886d79615.setContent(html_1d8f3e55c119347dec7b4891e6ec49b9);
#
#
#
#         marker_7fb09b8db3c244ff1a5ddc6f386d95f6.bindPopup(popup_425dc90cd55d28aa452798a886d79615)
#         ;
#
#
#
#
#             var marker_bb983799c59cf35e153254931b773337 = L.marker(
#                 [4.9557, 97.0693],
#                 {}
#             ).addTo(marker_cluster_74347a1d029eac775f09c622e5f73e17);
#
#
#             var icon_a5467a55d247d0c7cd537679b7eb5151 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bb983799c59cf35e153254931b773337.setIcon(icon_a5467a55d247d0c7cd537679b7eb5151);
#
#
#         var popup_00d133f396ce0f398dcb534771a49cb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c42864ec35c63d8feab20f7198f3584f = $(`&lt;div id=&quot;html_c42864ec35c63d8feab20f7198f3584f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cot Girek&lt;/div&gt;`)[0];
#                 popup_00d133f396ce0f398dcb534771a49cb1.setContent(html_c42864ec35c63d8feab20f7198f3584
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14dc2bb71fd43d4b9b76199230718428 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14dc2bb71fd43d4b9b76199230718428&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14dc2bb71fd43d4b9b76199230718428 = L.map(
#                 &quot;map_14dc2bb71fd43d4b9b76199230718428&quot;,
#                 {
#                     center: [5.095344999999999, 97.045335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad6fb8b8296dde2c421ad5a735ae61bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ad6fb8b8296dde2c421ad5a735ae61bc.addTo(map_14dc2bb71fd43d4b9b76199230718428);
#
#
#             var marker_cluster_b5f452f69affc82d1a3d526345f65cdc = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_11f6bc58457ec3a62cd0ba637a623557 = L.marker(
#                 [5.1048, 96.8466],
#                 {}
#             ).addTo(marker_cluster_b5f452f69affc82d1a3d526345f65cdc);
#
#
#             var icon_3da7ed9ded08b7e80c029b606cd74096 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_11f6bc58457ec3a62cd0ba637a623557.setIcon(icon_3da7ed9ded08b7e80c029b606cd74096);
#
#
#         var popup_ebf13310357234f2b14c6b6a573e5be5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69834e34fe5e5809bc44b2ff18d48682 = $(`&lt;div id=&quot;html_69834e34fe5e5809bc44b2ff18d48682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baktiya: Awas&lt;/div&gt;`)[0];
#                 popup_ebf13310357234f2b14c6b6a573e5be5.setContent(html_69834e34fe5e5809bc44b2ff18d48682);
#
#
#
#         marker_11f6bc58457ec3a62cd0ba637a623557.bindPopup(popup_ebf13310357234f2b14c6b6a573e5be5)
#         ;
#
#
#
#
#             var marker_af4c36c579d3d1d21e27f02653b2d10c = L.marker(
#                 [5.0883, 96.8067],
#                 {}
#             ).addTo(marker_cluster_b5f452f69affc82d1a3d526345f65cdc);
#
#
#             var icon_eb4d298e5d65a1e40a42cdd658f2c370 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_af4c36c579d3d1d21e27f02653b2d10c.setIcon(icon_eb4d298e5d65a1e40a42cdd658f2c370);
#
#
#         var popup_1bb014f5f196d460749583d5e9d4269a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b148c65e0992ce9afac736c8eb0484ea = $(`&lt;div id=&quot;html_b148c65e0992ce9afac736c8eb0484ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baktiya Barat: Waspada&lt;/div&gt;`)[0];
#                 popup_1bb014f5f196d460749583d5e9d4269a.setContent(html_b148c65e0992ce9afac736c8eb0484ea);
#
#
#
#         marker_af4c36c579d3d1d21e27f02653b2d10c.bindPopup(popup_1bb014f5f196d460749583d5e9d4269a)
#         ;
#
#
#
#
#             var marker_abfc3aae511dfe2f3c7419ff2332fd67 = L.marker(
#                 [4.9557, 97.0693],
#                 {}
#             ).addTo(marker_cluster_b5f452f69affc82d1a3d526345f65cdc);
#
#
#             var icon_73ba203f089b663ee2cf60d502918d66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_abfc3aae511dfe2f3c7419ff2332fd67.setIcon(icon_73ba203f089b663ee2cf60d502918d66);
#
#
#         var popup_261815786bcffbea44bf335460ab33cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12b77561044dbece02f47d2bee786720 = $(`&lt;div id=&quot;html_12b77561044dbece02f47d2bee786720&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cot Girek: Waspada&lt;/div&gt;`)[0];
#                 popup_261815786bcffbea44bf335460ab33cb.setContent(html_
# Peta prediksi telah disimpan dalam file 'peta_prediksi.html'
